# %% [markdown]
# Spotify Data
#
# Timothy Wong

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('data.csv')
data.head(201)
# Out:
#      Position                     Track Name         Artist  Streams  \
# 0           1     Reggaetón Lento (Bailemos)           CNCO    19272
# 1           2                       Chantaje        Shakira    19270
# 2           3      Otra Vez (feat. J Balvin)  Zion & Lennox    15761
# 3           4                   Vente Pa' Ca   Ricky Martin    14954
# 4           5                         Safari       J Balvin    14269
# ..        ...                            ...            ...      ...
# 196       197               Una Cita - Remix      Alkilados     1233
# 197       198      Ella Es Mi Fiesta - Remix   Carlos Vives     1230
# 198       199  Sugar (feat. Francesco Yates)   Robin Schulz     1225
# 199       200                         Vuelve     Juan Magán     1223
# 200         1     Reggaetón Lento (Bailemos)           CNCO    16672
#
#                                                    URL        Date Region
# ...
